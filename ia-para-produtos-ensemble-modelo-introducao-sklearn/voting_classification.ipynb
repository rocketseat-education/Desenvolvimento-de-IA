# %%
# EDA
import pandas as pd
import plotly.express as px
import numpy as np

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %% [markdown]
# # Carregar Dados

# %%
# Carregar o dataset já tratado
df_leads = pd.read_csv('./datasets/leads_cleaned.csv')

# %%
# Mostrar as primeiras linhas
df_leads.head(10)
# Out:
#                Lead Origin     Lead Source  Do Not Email  Do Not Call  \
# 0                      API      Olark Chat             0            0
# 1                      API  Organic Search             0            0
# 2  Landing Page Submission  Direct Traffic             0            0
# 3  Landing Page Submission  Direct Traffic             0            0
# 4  Landing Page Submission          Google             0            0
# 5                      API      Olark Chat             0            0
# 6  Landing Page Submission          Google             0            0
# 7                      API      Olark Chat             0            0
# 8  Landing Page Submission  Direct Traffic             0            0
# 9                      API          Google             0            0
#
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
# 5          0          0.0                            0                   0.0
# 6          1          2.0                         1640                   2.0
# 7          0          0.0                            0                   0.0
# 8          0          2.0                           71                   2.0
# 9          0          4.0                           58                   4.0
#
#              Last Activity  Search  Newspaper Article  X Education Forums  \
# 0  Page Visited on Website       0                  0                   0
# 1             Email Opened       0                  0                   0
# 2             Email Opened       0                  0                   0
# 3              Unreachable       0                  0                   0
# 4        Converted to Lead       0                  0                   0
# 5  Olark Chat Conversation       0                  0                   0
# 6             Email Opened       0                  0                   0
# 7  Olark Chat Conversation       0                  0                   0
# 8             Email Opened       0                  0                   0
# 9             Email Opened       0                  0                   0
#
#    Newspaper  Digital Advertisement  Through Recommendations  \
# 0          0                      0                        0
# 1          0                      0                        0
# 2          0                      0                        0
# 3          0                      0                        0
# 4          0                      0                        0
# 5          0                      0                        0
# 6          0                      0                        0
# 7          0                      0                        0
# 8          0                      0                        0
# 9          0                      0                        0
#
#    A free copy of Mastering The Interview Last Notable Activity
# 0                                       0              Modified
# 1                                       0          Email Opened
# 2                                       1          Email Opened
# 3                                       0              Modified
# 4                                       0              Modified
# 5                                       0              Modified
# 6                                       0              Modified
# 7                                       0              Modified
# 8                                       1          Email Opened
# 9                                       0          Email Opened

# %%
# Mostrar as últimas linhas
df_leads.tail(10)
# Out:
#                   Lead Origin     Lead Source  Do Not Email  Do Not Call  \
# 9064  Landing Page Submission          Google             0            0
# 9065  Landing Page Submission          Google             0            0
# 9066  Landing Page Submission  Direct Traffic             0            0
# 9067                      API  Direct Traffic             0            0
# 9068  Landing Page Submission  Direct Traffic             0            0
# 9069  Landing Page Submission  Direct Traffic             1            0
# 9070  Landing Page Submission  Direct Traffic             0            0
# 9071  Landing Page Submission  Direct Traffic             1            0
# 9072  Landing Page Submission          Google             0            0
# 9073  Landing Page Submission  Direct Traffic             0            0
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 9064          0          2.0                          870
# 9065          1          8.0                         1016
# 9066          0          2.0                         1770
# 9067          1         13.0                         1409
# 9068          1          5.0                          210
# 9069          1          8.0                         1845
# 9070          0          2.0                          238
# 9071          0          2.0                          199
# 9072          1          3.0                          499
# 9073          1          6.0                         1279
#
#       Page Views Per Visit      Last Activity  Search  Newspaper Article  \
# 9064                  2.00       Email Opened       0                  0
# 9065                  4.00       Email Opened       0                  0
# 9066                  2.00           SMS Sent       0                  0
# 9067                  2.60           SMS Sent       0                  0
# 9068                  2.50           SMS Sent       0                  0
# 9069                  2.67  Email Marked Spam       0                  0
# 9070                  2.00           SMS Sent       0                  0
# 9071                  2.00           SMS Sent       0                  0
# 9072                  3.00           SMS Sent       0                  0
# 9073                  3.00           SMS Sent       0                  0
#
#       X Education Forums  Newspaper  Digital Advertisement  \
# 9064                   0          0                      0
# 9065                   0          0                      0
# 9066                   0          0                      0
# 9067                   0          0                      0
# 9068                   0          0                      0
# 9069                   0          0                      0
# 9070                   0          0                      0
# 9071                   0          0                      0
# 9072                   0          0                      0
# 9073                   0          0                      0
#
#       Through Recommendations  A free copy of Mastering The Interview  \
# 9064                        0                                       0
# 9065                        0                                       0
# 9066                        0                                       1
# 9067                        0                                       0
# 9068                        0                                       0
# 9069                        0                                       0
# 9070                        0                                       1
# 9071                        0                                       1
# 9072                        0                                       0
# 9073                        0                                       1
#
#      Last Notable Activity
# 9064          Email Opened
# 9065          Email Opened
# 9066              SMS Sent
# 9067              SMS Sent
# 9068              Modified
# 9069     Email Marked Spam
# 9070              SMS Sent
# 9071              SMS Sent
# 9072              SMS Sent
# 9073              Modified

# %%
# Mostrar estrutura do Dataset
df_leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9074 entries, 0 to 9073
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Lead Origin                             9074 non-null   object
#  1   Lead Source                             9074 non-null   object
#  2   Do Not Email                            9074 non-null   int64
#  3   Do Not Call                             9074 non-null   int64
#  4   Converted                               9074 non-null   int64
#  5   TotalVisits                             9074 non-null   float64
#  6   Total Time Spent on Website             9074 non-null   int64
#  7   Page Views Per Visit                    9074 non-null   float64
#  8   Last Activity                           9074 non-null   object
#  9   Search                                  9074 non-null   int64
#  10  Newspaper Article                       9074 non-null   int64
#  11  X Education Forums                      9074 non-null   int64
#  12  Newspaper                               9074 non-null   int64
#  13  Digital Advertisement                   9074 non-null   int64
#  14  Through Recommendations                 9074 non-null   int64
#  15  A free copy of Mastering The Interview  9074 non-null   int64
#  16  Last Notable Activity                   9074 non-null   object
# dtypes: float64(2), int64(11), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# # Preparação dos dados

# %%
# Preparar os dados (X e y)
X = df_leads.drop(columns=['Converted'])
y = df_leads['Converted']

# %%
# Usar Preprocessor já salvo
import joblib
preprocessor = joblib.load('./preprocessor_dataset_leads.pkl')

# %%
# Dividir dataset entre treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)

# Aplicar preprocessor
X_train = preprocessor.fit_transform(X_train).toarray()
X_test = preprocessor.transform(X_test).toarray()

# %%
# Mostrar a estrutura dos conjuntos
print(f'Conjunto de Treinamento: {X_train.shape}')
print(f'Conjunto de testes: {X_test.shape}')
# Out:
# Conjunto de Treinamento: (7259, 68)
# Conjunto de testes: (1815, 68)

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num__Do Not Email', 'num__Do Not Call', 'num__TotalVisits',
#        'num__Total Time Spent on Website', 'num__Page Views Per Visit',
#        'num__Search', 'num__Newspaper Article', 'num__X Education Forums',
#        'num__Newspaper', 'num__Digital Advertisement',
#        'num__Through Recommendations',
#        'num__A free copy of Mastering The Interview',
#        'cat__Lead Origin_API', 'cat__Lead Origin_Landing Page Submission',
#        'cat__Lead Origin_Lead Add Form', 'cat__Lead Origin_Lead Import',
#        'cat__Lead Source_Click2call', 'cat__Lead Source_Direct Traffic',
#        'cat__Lead Source_Facebook', 'cat__Lead Source_Google',
#        'cat__Lead Source_Live Chat', 'cat__Lead Source_NC_EDM',
#        'cat__Lead Source_Olark Chat', 'cat__Lead Source_Organic Search',
#        'cat__Lead Source_Pay per Click Ads', 'cat__Lead Source_Reference',
#        'cat__Lead Source_Referral Sites', 'cat__Lead Source_Social Media',
#        'cat__Lead Source_WeLearn', 'cat__Lead Source_Welingak Website',
#        'cat__Lead Source_bing', 'cat__Lead Source_blog',
#        'cat__Lead Source_testone', 'cat__Lead Source_welearnblog_Home',
#        'cat__Lead Source_youtubechannel',
#        'cat__Last Activity_Approached upfront',
#        'cat__Last Activity_Converted to Lead',
#        'cat__Last Activity_Email Bounced',
#        'cat__Last Activity_Email Link Clicked',
#        'cat__Last Activity_Email Marked Spam',
#        'cat__Last Activity_Email Opened',
#        'cat__Last Activity_Email Received',
#        'cat__Last Activity_Form Submitted on Website',
#        'cat__Last Activity_Had a Phone Conversation',
#        'cat__Last Activity_Olark Chat Conversation',
#        'cat__Last Activity_Page Visited on Website',
#        'cat__Last Activity_Resubscribed to emails',
#        'cat__Last Activity_SMS Sent', 'cat__Last Activity_Unreachable',
#        'cat__Last Activity_Unsubscribed',
#        'cat__Last Activity_View in browser link Clicked',
#        'cat__Last Activity_Visited Booth in Tradeshow',
#        'cat__Last Notable Activity_Approached upfront',
#        'cat__Last Notable Activity_Email Bounced',
#        'cat__Last Notable Activity_Email Link Clicked',
#        'cat__Last Notable Activity_Email Marked Spam',
#        'cat__Last Notable Activity_Email Opened',
#        'cat__Last Notable Activity_Email Received',
#        'cat__Last Notable Activity_Form Submitted on Website',
#        'cat__Last Notable Activity_Had a Phone Conversation',
#        'cat__Last Notable Activity_Modified',
#        'cat__Last Notable Activity_Olark Chat Conversation',
#        'cat__Last Notable Activity_Page Visited on Website',
#        'cat__Last Notable Activity_Resubscribed to emails',
#        'cat__Last Notable Activity_SMS Sent',
#        'cat__Last Notable Activity_Unreachable',
#        'cat__Last Notable Activity_Unsubscribed',
#        'cat__Last Notable Activity_View in browser link Clicked'],
#       dtype=object)

# %% [markdown]
# # Treinamento do Modelo de Voting Classifier

# %%
# Criar o modelo de VotingClassifier

lr_model = LogisticRegression(random_state=51)
svc_model = SVC(kernel='linear')
tree_model = DecisionTreeClassifier(random_state=51)

voting_model_hard = VotingClassifier(
    estimators = [
        ('logistic regression', lr_model),
        ('svc', svc_model),
        ('decision tree', tree_model)
    ],
    # Hard faz a votação pela maioria das predições dos estimadores
    # Soft faz a votação pela média das probabilidades de cada classe vindas de cada estimador
    voting='hard'
)

# %%
# Treinar o modelo
voting_model_hard.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('logistic regression',
#                               LogisticRegression(random_state=51)),
#                              ('svc', SVC(kernel='linear')),
#                              ('decision tree',
#                               DecisionTreeClassifier(random_state=51))])

# %% [markdown]
# # Análise dos Resultados

# %%
# Realizar predições no conjunto de testes
y_pred = voting_model_hard.predict(X_test)

# %%
# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
# Mostrar métricas
print(f'Acurácia: {accuracy}')
print(f'Precisão: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Acurácia: 0.7983471074380165
# Precisão: 0.7420382165605095
# Recall: 0.6955223880597015
# F1 Score: 0.7180277349768875

# %%
# Mostrar a matriz de confusão
conf_matrix = confusion_matrix(y_test, y_pred)

fig = px.imshow(conf_matrix,
                labels=dict(x='Predição', y='Real', color='Contagem'),
                x=['Not Converted', 'Converted'],
                y=['Not Converted', 'Converted'],
                color_continuous_scale='Viridis')

fig.update_traces(text=conf_matrix, texttemplate="%{z}")
fig.update_layout(coloraxis_showscale=False)

fig.show()
# Out:
# <div>                            <div id="a0f8e799-5e55-410b-a3fb-e88271f915c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0f8e799-5e55-410b-a3fb-e88271f915c4")) {                    Plotly.newPlot(                        "a0f8e799-5e55-410b-a3fb-e88271f915c4",                        [{"coloraxis":"coloraxis","name":"0","x":["Not Converted","Converted"],"y":["Not Converted","Converted"],"z":[[983,162],[204,466]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Predi\u00e7\u00e3o: %{x}\u003cbr\u003eReal: %{y}\u003cbr\u003eContagem: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","text":[[983,162],[204,466]],"texttemplate":"%{z}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","ma ...

# %% [markdown]
# ## Análise de Importância

# %%
# Carregar as importâncias dos modelos

importances = []

for estimador in voting_model_hard.estimators_:
    # Pra modelos lineares, retorna coef
    if hasattr(estimador, 'coef_'):
        importances.append(np.abs(estimador.coef_[0]))
    # Para modelos baseados em árvores
    elif hasattr(estimador, 'feature_importances_'):
        importances.append(estimador.feature_importances_)
    else:
        print(f'Não foi possível carregar as importâncias do modelo {type(estimador).__name__}')

# %%
# Calcular a média das importâncias
importancia_media = np.mean(importances, axis=0)

# %%
# Nomes das features
feature_names = preprocessor.get_feature_names_out()

# %%
# Criar um Dataframe com nomes e importâncias das features
df_feature_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importancia_media})

# %%
# Ordenar o Dataframe pela importância
df_feature_importances = df_feature_importances.sort_values(by='Importance', ascending=True)

# %%
# Plotar a importância das features
fig = px.bar(df_feature_importances,
             x='Importance',
             y='Feature',
             orientation='h',
             title='Importância das Features (Voting Classifier)'
             )

fig.update_layout(height=1280, width=1000)

fig.show()
# Out:
# <div>                            <div id="c31bbef5-6186-46f9-92e0-a36259e4151e" class="plotly-graph-div" style="height:1280px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c31bbef5-6186-46f9-92e0-a36259e4151e")) {                    Plotly.newPlot(                        "c31bbef5-6186-46f9-92e0-a36259e4151e",                        [{"alignmentgroup":"True","hovertemplate":"Importance=%{x}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.005724458849174978,0.007278402756578432,0.010895486456373164,0.013546347829006803,0.02167268595772483,0.021770726967026643,0.028557173268310546,0.03318337753665586,0.03554339382178512,0.03587512777867772,0.03675622438794074,0.042625390679696847,0.0427740327198222,0.05419764550219378,0.054593212464787856,0.05729068915021005,0.058220453560765995,0.08172462856677758,0.08244887269346542,0.10067164823924384,0.10262642150996099,0.10926949725162294,0.1133444561928912,0.12090709846533505,0.12090709846533505,0.1245370082065041,0.1270706958146162,0.13783369907465112,0.14172052638193802,0.1540634485063285,0.16075804488394493,0.1852574481532903,0.19591515575069576,0.1997226365416068,0.2252385198008989,0.22973273116383497,0.24872688570765455,0.25233691778705053,0.2544167106303343,0.25843587234752824,0.27364251186164473,0.2992027879160308,0.3124691806979601,0.3187118897492163,0.32214602877406817,0.33244699591250676,0.33488184552205585,0.3504111347424938,0.35100332246044946,0.35476814044020116,0.3549632955479037,0.43163126178135786,0.4536662170308459,0.48054617374381303,0.4898440828904623,0.5261230920970651,0.5512946576611232,0.5709187587195022,0.5901714533189677,0.6050214797734018,0.6097976052695461,0.6221706543372132,0.6822895034170092,0.6832006172535351,0.8520643289626522,0.8861597700789018,0.909058562765372,1.331605263601499],"xaxis":"x","y":["num__Digital Advertisement","num__Search","cat__Lead Source_Live Chat","num__A free copy of Mastering The Interview","cat__Last Activity_Email Link Clicked","cat__Last Activity_Visited Booth in Tradeshow","cat__Last Notable Activity_Unsubscribed","cat__Last Notable Activity_Approached upfront","num__Newspaper Article","num__Do Not Call","num__Through Recommendations","num__Newspaper","cat__Lead Source_Pay per Click Ads","cat__Last Activity_View in browser link Clicked","cat__Lead Source_testone","num__X Education Forums","cat__Last Notable Activity_Form Submitted on Website","cat__Lead Source_youtubechannel","num__Page Views Per Visit","cat__Last Activity_Email Opened","cat__Last Activity_Unsubscribed","cat__Lead Source_bing","num__TotalVisits","cat__Last Activity_Email Marked Spam","cat__Last Notable Activity_Email Marked Spam","cat__Lead Source_Google","cat__Lead Origin_Lead Import","cat__Last Notable Activity_Email Received","cat__Lead Source_welearnblog_Home","cat__Lead Source_Click2call","cat__Last Activity_SMS Sent","cat__Last Notable Activity_Email Bounced","cat__Lead Source_WeLearn","cat__Lead Source_Organic Search","num__Do Not Email","cat__Last Activity_Unreachable","cat__Last Notable Activity_Page Visited on Website","cat__Last Activity_Form Submitted on Website","cat__Last Notable Activity_View in browser link Clicked","cat__Lead Source_Referral Sites","cat__Lead Source_Reference","cat__Last Activity_Email Received","cat__Lead Source_NC_EDM","cat__Last Activity_Page Visited on Website","cat__Lead Source_Olark Chat","cat__Lead Source_Direct Traffic","cat__Lead Source_blog","cat__Last Notable Activity_SMS Sent","cat__Lead Source_Social Media","cat__Last Notable Activity_Resubscribed to emails","cat__Last Activity_Resubscribed to emails","cat__Lead Source_Facebook","cat__Last Notable  ...
